# %% [markdown]
# ### SVMs y optimización de hiperparámetros
#
# En este notebook trabajaremos con un dataset simulado de eventos del experimento ATLAS. Cada fila representa un evento de colisión protón–protón, y cada columna corresponde a una variable reconstruida a partir de los objetos físicos detectados en el evento: jets, leptones, energía faltante, etc.
#
# El objetivo es distinguir entre dos tipos de eventos:
#
# - **`ttbar`**: producción de un par top–antitop. Es un proceso mucho más frecuente.
# - **`4top`**: producción de cuatro quarks top. Es un proceso mucho más raro y corresponde a nuestra clase positiva.
#
#
# Basado en Machine learning for physics and Astronomy, Viviana Acquaviva (2023)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.svm import SVC, LinearSVC # Nuevo algoritmo!
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_predict, cross_validate
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn import metrics
from sklearn.model_selection import GridSearchCV # Nuevo! Para explorar los hiperparámetros del modelo

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 100)
rc('text', usetex=False)

# %% [markdown]
# Leemos las características y las etiquetas

# %%
features = pd.read_csv('ParticleID_features.csv', index_col='ID')

# %%
features.head(10)
# Out:
#           MET    METphi Type_1        P1        P2        P3        P4 Type_2  \
# ID
# 0    62803.50 -1.810010      j  137571.0  128444.0 -0.345744 -0.307112      j
# 1    57594.20 -0.509253      j  161529.0   80458.3 -1.318010  1.402050      j
# 2    82313.30  1.686840      b  167130.0  113078.0  0.937258 -2.068680      j
# 3    30610.80  2.617120      j  112267.0   61383.9 -1.211050 -1.457800      b
# 4    45153.10 -2.241350      j  178174.0  100164.0  1.166880 -0.018721      j
# 5    43803.10  0.572184      b  146274.0  111016.0 -0.776311  1.083980      j
# 6    28100.40 -0.593429      j  458244.0  391557.0 -0.546723  0.013275      b
# 7   166458.00  0.473635      j  848058.0  273398.0 -1.794510  2.763560      j
# 8     4664.13 -1.828120      j  477219.0  331550.0 -0.899484  0.698675      b
# 9    17426.90  1.363170      j   74241.5   71823.2 -0.228244 -1.755950      j
#
#            P5        P6        P7        P8 Type_3        P9       P10  \
# ID
# 0    174209.0  127932.0  0.826569  2.332000      b   86788.9   84554.9
# 1    291490.0   68462.9 -2.126740 -2.582310     e-   44270.1   35139.6
# 2    102423.0   54922.3  1.226850  0.646589      j   60768.9   36244.3
# 3     40647.8   39472.0 -0.024646 -2.222800      j  201589.0   32978.6
# 4     92351.3   69762.1  0.774114  2.568740      j   61625.2   50086.7
# 5   1036150.0  109475.0 -2.937790 -1.518380      j  259026.0   71613.8
# 6    425427.0  328566.0 -0.728581 -2.411570      j  126694.0  116820.0
# 7    267149.0  242308.0 -0.425923 -1.534860      b  461064.0  159944.0
# 8    696365.0  246682.0 -1.697140 -2.285070      j  987005.0   62516.5
# 9     60026.7   54692.0  0.414105  1.453790      j  217944.0   53033.2
#
#          P11       P12 Type_4       P13       P14       P15       P16 Type_5  \
# ID
# 0  -0.180795  2.187970      j  140289.0   76955.8 -1.199330 -1.302800     m+
# 1  -0.706120 -0.371392     e+   72883.9   26902.2 -1.653860 -3.129630    NaN
# 2   1.102890 -1.434480      j   77714.0   27801.5  1.684610  1.389690      j
NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 1        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 2        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 3        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 4        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 5        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 6        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 7   0.315873     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 8        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
# 9        NaN     NaN  NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN     NaN
#
#     P45  P46  P47  P48 Type_13  P49  P50  P51  P52
# ID
# 0   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN
# 9   NaN  NaN  NaN  NaN     NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# Cada fila del dataset corresponde a un evento de colisión protón-protón.
# Para cada evento se conoce:
# - Energía faltante:
#   - `MET`: energía transversa faltante (*missing transverse energy*)
#   - `METphi`: ángulo azimutal asociado a la dirección de la energía faltante
# - Información de cada partícula reconstruida: Para cada partícula se registra:
#     - Tipo de partícula, que puede ser: electrón, positrón, fotón, jet, b-jet, muón con carga positiva, muón con carga negativa
#     - 4-vector, que describe la cinemática de la partícula. En este dataset, el 4-vector incluye: energía, momento transversal, pseudorapidez $\eta$ y ángulo azimutal $\phi$

# %%
features.shape
# Out:
# (5000, 67)

# %%
y = np.genfromtxt('ParticleID_labels.txt', dtype = str)

# %%
y
# Out:
# array(['ttbar', 'ttbar', 'ttbar', ..., 'ttbar', '4top', 'ttbar'],
#       dtype='<U5')

# %% [markdown]
# ### Objetivo del problema
#
# Queremos entrenar un clasificador que distinga entre dos tipos de eventos:
#
# - `ttbar`: producción de un par top-antitop.
# - `4top`: producción de cuatro quarks top.

# %% [markdown]
# #### Necesitamos transformar las dos categorías de targets desde un string a un valor numérico, como 0/1. Podemos usar la función [`LabelEncoder`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html) de sklearn

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() #cambia las categorías a 1...N

# %%
y
# Out:
# array(['ttbar', 'ttbar', 'ttbar', ..., 'ttbar', '4top', 'ttbar'],
#       dtype='<U5')

# %%
y = le.fit_transform(y)

# %%
le.classes_
# Out:
# array(['4top', 'ttbar'], dtype='<U5')

# %% [markdown]
# `LabelEncoder` asigna números a las clases en el orden definido por `le.classes_`.
# Como queremos que `4top` sea la clase positiva, revisamos la codificación y, si es necesario, invertimos las etiquetas.

# %%
target = np.abs(y - 1)

# %%
target # Ahora sí
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
y.shape
# Out:
# (5000,)

# %% [markdown]
# #### Echemos un vistazo a las características

# %%
features.describe() #Esto excluye a las columnas con datos no-numéricos
# Out:
#                  MET       METphi            P1            P2           P3  \
# count    5000.000000  5000.000000  5.000000e+03  5.000000e+03  5000.000000
# mean    64071.074332    -0.028916  3.301357e+05  1.540486e+05    -0.039812
# std     60525.122480     1.819257  3.068202e+05  1.149469e+05     1.361762
# min       290.756000    -3.141010  3.857940e+04  2.825400e+04    -4.110220
# 25%     24352.375000    -1.619905  1.369522e+05  8.883690e+04    -1.035570
# 50%     46814.400000    -0.055612  2.263525e+05  1.182015e+05    -0.038731
# 75%     83032.350000     1.537323  4.077158e+05  1.771265e+05     0.943598
# max    692674.000000     3.141130  3.186360e+06  1.276710e+06     4.141410
#
#                 P4            P5            P6           P7           P8  \
# count  5000.000000  4.997000e+03  4.997000e+03  4997.000000  4997.000000
#
# Esto puede ser razonable, pero también puede introducir una señal artificial: el modelo podría aprender no solo de las variables físicas, sino también de cuántas partículas fueron registradas.
#
#
# **¿Qué podemos hacer?**

# %% [markdown]
# #### Opción 1: Sólo considerar las primeras 16 columnas (4 primeros productos)
#
# De esta forma, reducimos los problemas de manipulación o de imputación de datos faltantes.
#
#
# Tenemos un trade-off entre tener más features, pero si tenemos más, tendremos muchos datos faltantes que tendremos que reemplazar (imputing), o mantenemos menos features, pero el problema es más simple

# %%
#limitamos los features
features_lim = features[['MET', 'METphi', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11',
       'P12',  'P13', 'P14', 'P15', 'P16']]

# %%
features_lim.head()
# Out:
#         MET    METphi        P1        P2        P3        P4        P5  \
# ID
# 0   62803.5 -1.810010  137571.0  128444.0 -0.345744 -0.307112  174209.0
# 1   57594.2 -0.509253  161529.0   80458.3 -1.318010  1.402050  291490.0
# 2   82313.3  1.686840  167130.0  113078.0  0.937258 -2.068680  102423.0
# 3   30610.8  2.617120  112267.0   61383.9 -1.211050 -1.457800   40647.8
# 4   45153.1 -2.241350  178174.0  100164.0  1.166880 -0.018721   92351.3
#
#           P6        P7        P8        P9      P10       P11       P12  \
# ID
# 0   127932.0  0.826569  2.332000   86788.9  84554.9 -0.180795  2.187970
# 1    68462.9 -2.126740 -2.582310   44270.1  35139.6 -0.706120 -0.371392
# 2    54922.3  1.226850  0.646589   60768.9  36244.3  1.102890 -1.434480
# 3    39472.0 -0.024646 -2.222800  201589.0  32978.6 -2.496040  1.137810
# 4    69762.1  0.774114  2.568740   61625.2  50086.7  0.652572 -3.012800
#
#          P13      P14      P15       P16
# ID
# 0   140289.0  76955.8 -1.19933 -1.302800
# 1    72883.9  26902.2 -1.65386 -3.129630
# 2    77714.0  27801.5  1.68461  1.389690
# 3    90096.7  26964.5  1.87132  0.817631
# 4   104193.0  31151.0  1.87641  0.865381

# %%
features_lim.describe()
# Out:
#                  MET       METphi            P1            P2           P3  \
# count    5000.000000  5000.000000  5.000000e+03  5.000000e+03  5000.000000
# mean    64071.074332    -0.028916  3.301357e+05  1.540486e+05    -0.039812
# std     60525.122480     1.819257  3.068202e+05  1.149469e+05     1.361762
# min       290.756000    -3.141010  3.857940e+04  2.825400e+04    -4.110220
# 25%     24352.375000    -1.619905  1.369522e+05  8.883690e+04    -1.035570
# 50%     46814.400000    -0.055612  2.263525e+05  1.182015e+05    -0.038731
# 75%     83032.350000     1.537323  4.077158e+05  1.771265e+05     0.943598
# max    692674.000000     3.141130  3.186360e+06  1.276710e+06     4.141410
#
#                 P4            P5            P6           P7           P8  \
# count  5000.000000  4.997000e+03  4.997000e+03  4997.000000  4997.000000
# mean     -0.003049  2.527799e+05  1.080302e+05    -0.029936     0.007327
# std       1.814855  2.638580e+05  8.136261e+04     1.439105     1.828832
# min      -3.140710  1.087540e+04  1.080000e+04    -4.668790    -3.140530
# count  5.000000e+03    5000.000000  5000.000000  5000.000000  5.000000e+03
# mean   2.096800e+05   74114.709700    -0.024853     0.011727  1.703778e+05
# std    2.506651e+05   46675.655162     1.569410     1.793678  2.352279e+05
# min    0.000000e+00       0.000000    -4.520250    -3.141480  0.000000e+00
# 25%    7.488228e+04   46165.375000    -1.108390    -1.532478  5.480870e+04
# 50%    1.277135e+05   62167.100000    -0.023321     0.006687  9.259335e+04
# 75%    2.406498e+05   89065.300000     1.048617     1.553310  1.831228e+05
# max    2.800410e+06  788338.000000     4.798090     3.139020  2.503590e+06
#
#                  P14          P15          P16
# count    5000.000000  5000.000000  5000.000000
# mean    54046.489280     0.010116     0.042704
# std     33795.723384     1.587146     1.760070
# min         0.000000    -4.616550    -3.136130
# 25%     33959.400000    -1.050477    -1.424080
# 50%     47278.800000     0.000000     0.000000
# 75%     66846.300000     1.085627     1.521765
# max    481884.000000     4.730480     3.139660

# %% [markdown]
# Ahora tenemos tamaños consistentes para poder usarlos como features, PERO hay que estar conciente de los efectos negativos que puede traer nuestra estrategia de imputación

# %% [markdown]
# ## Benchmark inicial
#
# En este notebook, el benchmark principal es el desempeño de estrategias simples antes de usar un SVM más flexible. Primero comparamos contra un clasificador que siempre predice la clase mayoritaria, ya que el dataset está desbalanceado. Luego, un clasificador aleatorio, es decir, asigna un valor aleatorio a cada clase. Y también usamos un `LinearSVC` con escalamiento como benchmark lineal: una referencia razonable para saber si necesitamos modelos más complejos, como SVM con kernels no lineales.

# %%
np.sum(target)/len(target) #distribución
# Out:
# 0.1622

# %% [markdown]
# 84\% en la etiqueta negativa, 16\% en la etiqueta positiva.
#
# Esto significa que un clasificador que pone todo en la clase negativa (lazy classifier) tendrá un 84% de accuracy

# %% [markdown]
# Cómo lo haría un clasificador aleatorio que asigna un valor aleatorio a la distribución de clase?

# %%
#Numerical solution

acc=0
for i in range(1000): #1000 iteraciones del proceso
    x = np.random.choice(target,5000) #generamos 5000 etiquetas aleatorias
    acc += metrics.accuracy_score(target,x) #calculamos accuracy promedio en las 1000 iteraciones
print(acc/1000)

#Analytic solution 
#P(Clase 1)^2 + P(Clase 2)^2 exactitud esperada
 

print(0.8378*(0.8378) + 0.1622*0.1622)
# Out:
# 0.7285531999999995
# 0.72821768

# %% [markdown]
# En conclusión, un clasificador aleatorio tendrá 73% accuracy, un lazy classfier tiene 83% accuracy. Este análisis es útil para tener una expectativa de qué es un "buen resultado" y qué significa una mejora significativa

# %% [markdown]
# ### Ahora empezaremos con un modelo lineal  model = SVC()

# %% [markdown]
# Definimos una estrategia CV, establecemos un benchmark para un modelo lineal no regularization (parámetro C muy alto)
#
# **Antes de correr el modelo, discuta:**
#
# 1. ¿Esperamos que un modelo lineal separe bien eventos `ttbar` y `4top`?
# 2. ¿Qué significaría que el modelo lineal tenga una accuracy cercana al clasificador mayoritario?
# 3. ¿Qué métrica sería más relevante si queremos detectar eventos `4top`: accuracy, precision, recall o F1-score?
#
# - No pues la relación involucra más de una variable que difícilmente podrían tener una relación lineal entre sí. No es lo más usual
# - Que no es un buen modelo, pues el mínimo de accuracy que esperamos es el del clasificador mayoritario: esa es la base donde partimos nuestra evaluación.
# - recall. Buscamos recuperar la mayor cantidad de eventos reales posibles.

# %%
bmodel = LinearSVC(dual = False, C=1000) 
# Para modelo lineal, se prefiere dual=False cuando  n_samples > n_features.
#( el primal trabaja con las features, el dual trabaja con los alpha_i que estan asociados al numero de muestras)
# Si no, no va a converger!

# %% [markdown]
# **Qué signifca la elección de C grande?**
# Penalizaremos más los errores de clasificación y obtendremos un margen más estrecho de separación.

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=101)

# %%
l_benchmark_lim = cross_validate(bmodel, features_lim, target, cv = cv, scoring = 'accuracy', return_train_score=True)

# %%
l_benchmark_lim
# Out:
# {'fit_time': array([0.01248813, 0.00861931, 0.00615788, 0.00668907, 0.00684643]),
#  'score_time': array([0.02404404, 0.0014143 , 0.00142503, 0.00170732, 0.0011785 ]),
#  'test_score': array([0.841, 0.825, 0.829, 0.83 , 0.833]),
#  'train_score': array([0.8315 , 0.83275, 0.8315 , 0.83125, 0.832  ])}

# %%
np.round(l_benchmark_lim['test_score'].mean(),3), np.round(l_benchmark_lim['test_score'].std(), 3)
# Out:
# (0.832, 0.005)

# %% [markdown]
# El promedio de accuracy para este caso parece alto, pero es igual de alto que el lazy classifier.
# Podemos chequear las etiquetas con `cross_val_predict`, que compila las etiquetas predichas cuando cada objeto estaba en el fold test

# %%
ypred_bench_lim = cross_val_predict(bmodel, features_lim, target, cv = cv)

# %%
ypred_bench_lim
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# ### Pregunta: Qué podríamos haber hecho antes de haber construído el modelo SVM?

# %% [markdown]
# <details>
# <summary>Mostrar explicación</summary>
#
# ### Escalar!
#
# Los SVM son sensibles a la escala de las variables porque trabajan en el espacio de características.
# La optimización  depende de productos punto entre pares de ejemplos:
#
# $$
# \mathbf{x}_i \cdot \mathbf{x}_j
# $$
#
# Por eso escalamos las features antes de entrenar un SVM. Una opción común es usar `StandardScaler`, que transforma cada feature para que tenga media 0 y desviación estándar 1.
#
#
#
# </details>

# %%
from sklearn.pipeline import make_pipeline #Podemos construir varios pasos al mismo tiempo

# %% [markdown]
# ¿Por qué usamos Pipeline?
#
# Porque en validación cruzada, el escalamiento debe aprenderse usando solo los datos de entrenamiento de cada fold.
# Si escalamos todo el dataset antes de hacer CV, estaríamos usando información del conjunto de prueba para transformar los datos.
# Eso sería una forma sutil de data leakage.
#
# [`make_pipeline`](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.make_pipeline.html)  permite encadenar varios pasos de preprocesamiento y modelado en un solo objeto.

# %%
piped_model = make_pipeline(StandardScaler(), LinearSVC(dual = False, C = 1000))

# %%
#modelo benchmark (de referencia)
benchmark_lim_piped = cross_validate(piped_model, features_lim, target, cv = cv, scoring = 'accuracy', return_train_score=True)

# %%
benchmark_lim_piped
# Out:
# {'fit_time': array([0.00692177, 0.00677085, 0.00594783, 0.00711465, 0.00911975]),
#  'score_time': array([0.00163269, 0.00295496, 0.00161719, 0.00316668, 0.00264001]),
#  'test_score': array([0.894, 0.889, 0.89 , 0.892, 0.899]),
#  'train_score': array([0.89575, 0.895  , 0.895  , 0.89825, 0.89275])}

# %%
np.round(benchmark_lim_piped['test_score'].mean(),3), np.round(benchmark_lim_piped['test_score'].std(), 3)
# Out:
# (0.893, 0.004)

# %%
np.round(benchmark_lim_piped['train_score'].mean(),3), np.round(benchmark_lim_piped['train_score'].std(), 3)
# Out:
# (0.895, 0.002)

# %% [markdown]
# Esto es una mejora!
#
#
# Ahora necesitamos **diagnosticar** nuestro modelo:
#
# Si comparamos el score para prueba y entrenamiento, notamos que hay un problema....
# Miremos la curva de aprendizaje, que nos ayudará a mirar esto mejor y nos indicará si necesitamos más datos

# %% [markdown]
# ### Curva de aprendizaje

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=5,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5), scoring = 'accuracy', scale = False):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("# of training examples",fontsize = 14)
 
    plt.ylabel("Accuracy score",fontsize = 14)
    
    if (scale == True):
        scaler = sklearn.preprocessing.StandardScaler()
        X = scaler.fit_transform(X)
    
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring = scoring)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
#    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="b")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="b",
             label="Training score from CV")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Test score from CV")

    plt.legend(loc="best",fontsize = 12)
    return plt

# %%
cv
# Out:
# StratifiedKFold(n_splits=5, random_state=101, shuffle=True)

# %%
plot_learning_curve(piped_model, 'Generalized Learning Curves, linear SVC model, no reg', 
                    features_lim, target, train_sizes = np.array([0.05,0.1,0.2,0.5,1.0]), cv = cv)
# Out:
# <module 'matplotlib.pyplot' from '/home/benja/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
# Obtener predicciones usando validación cruzada
ypred_linear = cross_val_predict(
    piped_model,
    features_lim,
    target,
    cv=cv
)

# %% [markdown]
# #### Genere una matriz de confusión para esre modelo y evalúe el desempeño del modelo a partir del resultado.
#
# también puede usar la función [`classification_report`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html) de `sklearn`

# %%
cm = metrics.confusion_matrix(target, ypred_linear)
tn, fp, fn, tp = cm.ravel()

acc = metrics.accuracy_score(target, ypred_linear)
prec = metrics.precision_score(target, ypred_linear)
rec = metrics.recall_score(target, ypred_linear)
f1 = metrics.f1_score(target, ypred_linear)

print("Matriz de confusión:\n", cm)
print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
print(f"Accuracy: {acc:.4f}")
print(f"Precision (4top): {prec:.4f}")
print(f"Recall (4top): {rec:.4f}")
print(f"F1-score (4top): {f1:.4f}\n")
print("Classification report:\n", metrics.classification_report(target, ypred_linear, digits=4))
# Out:
# Matriz de confusión:
#  [[4048  141]
#  [ 395  416]]
# TN: 4048, FP: 141, FN: 395, TP: 416
# Accuracy: 0.8928
# Precision (4top): 0.7469
# Recall (4top): 0.5129
# F1-score (4top): 0.6082
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9111    0.9663    0.9379      4189
#            1     0.7469    0.5129    0.6082       811
#
#     accuracy                         0.8928      5000
#    macro avg     0.8290    0.7396    0.7730      5000
# weighted avg     0.8845    0.8928    0.8844      5000

# %% [markdown]
# ## Conclusiones del benchmark lineal
#
# 1. En la curva de aprendizaje, ¿los scores de entrenamiento y validación son altos o bajos?
#    ¿Están separados o son parecidos?
#
# 2. ¿La curva sugiere alto bias o alta variance?
#    Justifique usando la relación entre score de entrenamiento y validación.
#
# 3. Considerando que usamos \(C=1000\), ¿qué nos dice este resultado sobre la capacidad del modelo lineal?
#
# 4. En la matriz de confusión, ¿el modelo detecta bien los eventos `4top` o tiende a clasificarlos como `ttbar`?
#
# 5. ¿qué métrica muestra mejor el problema con la clase minoritaria: accuracy, precision, recall o F1-score?
#
# 6. ¿El modelo lineal supera realmente los benchmarks ingenuos, o su buen desempeño se explica principalmente por el desbalance de clases?
#
# 7. ¿Qué evidencia nos indica que necesitamos un modelo más flexible que una frontera lineal?
#
# - Son bajos considerando que el lazy classifier estaba en 84%. Al final de la curva, son bastante parecidos.
# - Tenemos alto bias, pues las métricas no son muy altas, y además no se presenta una diferencia abismal entre entrenamiento y validación, característica de una alta varianza
# - Pese a que se trataron de minimizar los errores con la elección de C, el modelo no fue capaz de aumentar considerablemente su desempeño en el training set. Básicamente no es un buen modelo para el problema, y es necesario agregar features o complejizar.
# - Recall. Es muy baja (50%), y no está recuperando los TP.
# - Desde `classification_report` notamos como las métricas son mucho mejores para la clase negativa que para la positiva, y esto se explica por el desbalance de clases presente en los datos. El modelo lineal no es realmente mejor a los benchmarks iniciales.
# - Los resultados de la curva de aprendizaje y el recall nos sugieren que necesitamos un modelo más complejo para obtener mejores clasificaciones.

# %% [markdown]
# ## Optimización de hiperparámetros
#
# [`GridSearchCV`](https://scikit-learn.org/stable/modules/grid_search.html)selecciona los hiperparámetros que obtienen el mejor desempeño promedio en validación cruzada. Sin embargo, ese score puede ser optimista, porque los mismos folds de validación se usaron para elegir la mejor combinación de hiperparámetros.
# Para estimar mejor el desempeño esperado en datos nuevos, se puede usar **validación cruzada anidada**. En este procedimiento, una validación cruzada interna selecciona los hiperparámetros, mientras que una validación cruzada externa evalúa el modelo seleccionado.
# La idea central es no usar la misma información para elegir el modelo y para reportar su desempeño final.
#
# La validación cruzada anidada es más rigurosa, pero no siempre vale la pena implementarla. Puede ser muy costosa, porque requiere repetir la búsqueda de hiperparámetros dentro de cada fold externo.En este notebook usaremos `GridSearchCV` para seleccionar hiperparámetros y comparar modelos, pero debemos recordar que el mejor score obtenido puede ser algo optimista. Si el objetivo fuera reportar un resultado final de investigación de manera rigurosa, sería mejor usar un conjunto de prueba independiente o validación cruzada anidada.

# %%
#ahora usamos la version general SVC y no la lineal, para cambiar el kernel
piped_model = make_pipeline(StandardScaler(), SVC()) 

piped_model.get_params() # esto nos muestra los parámetros para el scaler y el clasificador
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()), ('svc', SVC())],
#  'transform_input': None,
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'svc': SVC(),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'svc__C': 1.0,
#  'svc__break_ties': False,
#  'svc__cache_size': 200,
#  'svc__class_weight': None,
#  'svc__coef0': 0.0,
#  'svc__decision_function_shape': 'ovr',
#  'svc__degree': 3,
#  'svc__gamma': 'scale',
#  'svc__kernel': 'rbf',
#  'svc__max_iter': -1,
#  'svc__probability': False,
#  'svc__random_state': None,
#  'svc__shrinking': True,
#  'svc__tol': 0.001,
#  'svc__verbose': False}

# %% [markdown]
# ### Podemos definir un diccionario de valores parámetros para correr la optimización
#
# Note que esto tomará tiempo (~3 min en mi computador)
#
# Una vez que corramos esta celda, el objeto modelo tendra atributos de "best_score_", "best_params_" y "best_estimator_", que nos da acceso al estimador óptimo y "cv_results_" que pueden ser utilizados para visualizar la performance de todos los modelo

# %%
# %%time
#optimizando SVC, TODAVIA NO ES CV ANIDADA!

#Probamos kernel polinomial y gaussiano, parámetros gamma y degree, 
# además del parámetro de regularización
parameters = {'svc__kernel':['poly', 'rbf'], \
              'svc__gamma':[0.00001,'scale', 0.01, 0.1], 'svc__C':[0.1, 1.0, 10.0, 100.0, 1000], \
              'svc__degree': [2, 4, 8]}

# CV para todos los valores de los parámetros del GridSearch
model = GridSearchCV(piped_model, parameters, cv = StratifiedKFold(n_splits=5, shuffle=True), \
                     verbose = 2, n_jobs = 4, return_train_score=True)
model.fit(features_lim,target)
print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.6s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.6s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.6s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   2.5s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   3.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   3.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   3.5s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   4.5s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   7.8s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   9.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   8.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=  11.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.6s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=  10.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=  25.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=  27.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=  31.6s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=  42.0s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=  33.7s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time= 1.4min
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time= 1.6min
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time= 1.5min
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.5s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time= 2.1min
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   0.4s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=1000, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time= 1.5min
# Best params, best score: 0.8964 {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# CPU times: user 2.34 s, sys: 766 ms, total: 3.11 s
# Wall time: 4min 28s

# %% [markdown]
# ####  Ahora, visualizamos los modelos en un dataframe, y los rankeamos de acuerdo a los scores de prueba.
#
# Miraremos el promedio y desviación estándar de los test scores, el promedio de los train scores, para evaluar si son distintos  y la significancia del resultado, y fitting time, para elegir el modelo más rápido en vez del mejor modelo, si es que los scores son comparables

# %%
scores_lim = pd.DataFrame(model.cv_results_)

scores_lim.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_svc__C', 'param_svc__degree', 'param_svc__gamma',
#        'param_svc__kernel', 'params', 'split0_test_score', 'split1_test_score',
#        'split2_test_score', 'split3_test_score', 'split4_test_score',
#        'mean_test_score', 'std_test_score', 'rank_test_score',
#        'split0_train_score', 'split1_train_score', 'split2_train_score',
#        'split3_train_score', 'split4_train_score', 'mean_train_score',
#        'std_train_score'],
#       dtype='object')

# %%
scores_lim[['params','mean_test_score','std_test_score','mean_train_score', \
            'mean_fit_time']].sort_values(by = 'mean_test_score', ascending = False)
# Out:
#                                                                                 params  \
# 69        {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 61        {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 53        {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 27      {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 43      {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 35      {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 31          {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 39          {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 47          {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 37         {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 29         {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 45         {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 105      {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 113      {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 97       {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 93       {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 85       {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 77       {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 51     {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 59     {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 67     {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 81      {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 73      {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 89      {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 5          {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 21         {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 13         {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 11      {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 3       {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 19      {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 63         {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 55         {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 71         {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 30         {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 50    {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 76      {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 109       {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 101       {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 117       {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# 100      {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 54        {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 78       {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 98    {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 102       {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 26     {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 74   {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 6          {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 52       {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 34     {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 111        {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 103        {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 119        {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 87        {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 79        {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 95        {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 108      {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 14         {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 66    {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 22         {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 83    {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 91    {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 75    {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 58    {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 38         {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 2      {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 42     {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 84      {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 28        {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 10     {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 99     {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 115    {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 107    {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# 90   {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 46         {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 18     {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 23          {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 15          {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 7           {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
# 60       {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 82   {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 62        {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 92      {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 116      {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 36        {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 4         {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 68       {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 106   {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 110       {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 86       {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 65       {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 57       {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 49       {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 118       {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 44        {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 114   {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 12        {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 70        {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 20        {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 94       {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 112     {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 9         {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 8        {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 16       {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 17        {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 72     {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 40       {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 24       {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 104     {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 25        {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 32       {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 33        {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 80     {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 41        {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 96      {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 48      {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 56      {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 1         {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}
# 88     {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 64      {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 0        {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 28            0.8660        0.007239           0.86675      -0.065631
# 10            0.8658        0.009368           0.88575       0.150301
# 99            0.8652        0.007859           1.00000       0.337809
# 115           0.8652        0.007859           1.00000       0.325746
# 107           0.8652        0.007859           1.00000       0.326859
# 90            0.8632        0.002315           0.97225       0.472314
# 46            0.8618        0.003487           0.97350       0.486546
# 18            0.8608        0.006493           0.90060       0.220814
# 23            0.8588        0.002315           0.86670       0.107510
# 15            0.8588        0.002315           0.86670       0.139676
# 7             0.8588        0.002315           0.86670       0.123896
# 60            0.8578        0.006705           0.86390       0.111110
# 82            0.8544        0.006344           0.99615       0.383033
# 62            0.8526        0.006406           0.99650       0.322457
# 92            0.8508        0.003187           0.85890       0.128859
# 116           0.8508        0.007359           0.86930       0.135418
# 36            0.8502        0.004400           0.85260       0.127965
# 4             0.8492        0.004020           0.84905       0.100981
# 68            0.8482        0.004167           0.85255       0.127227
# 106           0.8480        0.003795           1.00000       0.340130
# 110           0.8474        0.003262           1.00000       0.364613
# 86            0.8472        0.003487           1.00000       0.321122
# 65            0.8442        0.002786           0.84455       0.101514
# 57            0.8442        0.002786           0.84455       0.090861
# 49            0.8442        0.002786           0.84455       0.103705
# 118           0.8426        0.004128           1.00000       0.376698
# 44            0.8422        0.003187           0.84460       0.137156
# 114           0.8420        0.004648           0.99525       0.409925
# 12            0.8414        0.002728           0.84230       0.125675
# 70            0.8412        0.005528           0.99570       0.395395
# 20            0.8404        0.001625           0.84170       0.129694
# 94            0.8394        0.006800           0.99960       0.443910
# 112           0.8378        0.000400           0.83780       0.090813
# 9             0.8378        0.000400           0.83780       0.102867
# 8             0.8378        0.000400           0.83780       0.091072
# 16            0.8378        0.000400           0.83780       0.109068
# 17            0.8378        0.000400           0.83780       0.104540
# 72            0.8378        0.000400           0.83780       0.080599
# 40            0.8378        0.000400           0.83780       0.105741
# 24            0.8378        0.000400           0.83780       0.082822
# 104           0.8378        0.000400           0.83780       0.086062
# 25            0.8378        0.000400           0.83780       0.095829
# 32            0.8378        0.000400           0.83780       0.104658
# 33            0.8378        0.000400           0.83780       0.128109
# 80            0.8378        0.000400           0.83780       0.116122
# 41            0.8378        0.000400           0.83780       0.116670
# 96            0.8378        0.000400           0.83780       0.124674
# 48            0.8378        0.000400           0.83780       0.090312
# 56            0.8378        0.000400           0.83780       0.086665
# 1             0.8378        0.000400           0.83780       0.105988
# 88            0.8378        0.000400           0.83780       0.083652
# 64            0.8378        0.000400           0.83780       0.088615
# 0             0.8378        0.000400           0.83780       0.090871

# %% [markdown]
# Observamos que el kernel rbf es preferido constantemente, los valores de $C$ y $\gamma$ no afectan demasiado los scores. GridSearch es insensible a combinaciones de parámetros irrelevantes, por ejemplo, los tres primeros modelos son idénticos porque el grado del kernel polinomial no afecta al kernel rbf.

# %% [markdown]
# #### Podemos aislar un solo tipo de kernel

# %%
scores_lim[scores_lim['param_svc__kernel'] == 'poly'][['params','mean_test_score','std_test_score',\
                        'mean_train_score','mean_fit_time']].sort_values(by = 'mean_test_score', ascending = False)
# Out:
#                                                                                 params  \
# 50    {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 30         {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 76      {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 100      {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 54        {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 78       {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 98    {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 102       {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 26     {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 74   {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 52       {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 6          {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 34     {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 108      {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 14         {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 22         {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 58    {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 66    {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 38         {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 2      {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 42     {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 84      {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 28        {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 10     {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 90   {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 46         {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 18     {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 60       {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 82   {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 62        {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 92      {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 116      {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 36        {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 4         {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 68       {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 106   {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 110       {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 86       {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 118       {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 44        {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 114   {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 'scale', 'svc__kernel': 'poly'}
# 12        {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 70        {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 20        {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 0.01, 'svc__kernel': 'poly'}
# 94       {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 0.1, 'svc__kernel': 'poly'}
# 72     {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 24       {'svc__C': 1.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 8        {'svc__C': 0.1, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 112     {'svc__C': 1000, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 16       {'svc__C': 0.1, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 104     {'svc__C': 1000, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 40       {'svc__C': 1.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 32       {'svc__C': 1.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 80     {'svc__C': 100.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 96      {'svc__C': 1000, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 48      {'svc__C': 10.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 88     {'svc__C': 100.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 56      {'svc__C': 10.0, 'svc__degree': 4, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 64      {'svc__C': 10.0, 'svc__degree': 8, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
# 0        {'svc__C': 0.1, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'poly'}
#
#      mean_test_score  std_test_score  mean_train_score  mean_fit_time
# 50            0.8778        0.005192           0.88645       0.431663
# 30            0.8778        0.004622           0.88565       0.239512
# 76            0.8778        0.004622           0.88560       0.217628
# 100           0.8774        0.004224           0.88725       1.073707
# 54            0.8774        0.004224           0.88725       1.116185
# 78            0.8772        0.004445           0.88855       9.464894
# 98            0.8770        0.004050           0.88840      31.934646
# 102           0.8770        0.004099           0.88830      97.160578
# 26            0.8764        0.004317           0.88245       0.148670
# 74            0.8762        0.003970           0.88830       3.339144
# 52            0.8746        0.005122           0.87795       0.120537
# 6             0.8746        0.005122           0.87795       0.118030
# 34            0.8730        0.006293           0.91630       0.228190
# 108           0.8718        0.006177           0.91705       0.196142
# 14            0.8718        0.006177           0.91705       0.200505
# 22            0.8712        0.004490           0.94450       0.420563
# 58            0.8712        0.004445           0.96155       0.243517
# 66            0.8712        0.004534           0.94360       0.462413
# 38            0.8708        0.004354           0.96240       0.314739
# 2             0.8696        0.007605           0.87100       0.133422
# 42            0.8678        0.003816           0.91600       0.310911
# 84            0.8662        0.009196           0.88630       0.136474
# 28            0.8660        0.007239           0.86675      -0.065631
# 10            0.8658        0.009368           0.88575       0.150301
# 90            0.8632        0.002315           0.97225       0.472314
# 46            0.8618        0.003487           0.97350       0.486546
# 18            0.8608        0.006493           0.90060       0.220814
# 60            0.8578        0.006705           0.86390       0.111110
# 82            0.8544        0.006344           0.99615       0.383033
# 62            0.8526        0.006406           0.99650       0.322457
# 92            0.8508        0.003187           0.85890       0.128859
# 116           0.8508        0.007359           0.86930       0.135418
# 36            0.8502        0.004400           0.85260       0.127965
# 4             0.8492        0.004020           0.84905       0.100981
# 68            0.8482        0.004167           0.85255       0.127227
# 106           0.8480        0.003795           1.00000       0.340130
# 110           0.8474        0.003262           1.00000       0.364613
# 86            0.8472        0.003487           1.00000       0.321122
# 118           0.8426        0.004128           1.00000       0.376698
# 44            0.8422        0.003187           0.84460       0.137156
# 114           0.8420        0.004648           0.99525       0.409925
# 12            0.8414        0.002728           0.84230       0.125675
# 70            0.8412        0.005528           0.99570       0.395395
# 20            0.8404        0.001625           0.84170       0.129694
# 94            0.8394        0.006800           0.99960       0.443910
# 72            0.8378        0.000400           0.83780       0.080599
# 24            0.8378        0.000400           0.83780       0.082822
# 8             0.8378        0.000400           0.83780       0.091072
# 112           0.8378        0.000400           0.83780       0.090813
# 16            0.8378        0.000400           0.83780       0.109068
# 104           0.8378        0.000400           0.83780       0.086062
# 40            0.8378        0.000400           0.83780       0.105741
# 32            0.8378        0.000400           0.83780       0.104658
# 80            0.8378        0.000400           0.83780       0.116122
# 96            0.8378        0.000400           0.83780       0.124674
# 48            0.8378        0.000400           0.83780       0.090312
# 88            0.8378        0.000400           0.83780       0.083652
# 56            0.8378        0.000400           0.83780       0.086665
# 64            0.8378        0.000400           0.83780       0.088615
# 0             0.8378        0.000400           0.83780       0.090871

# %%
best_model = model.best_estimator_

ypred_best = cross_val_predict(
    best_model,
    features_lim,
    target,
    cv=cv
)

cm = metrics.confusion_matrix(target, ypred_best)
tn, fp, fn, tp = cm.ravel()
acc = metrics.accuracy_score(target, ypred_best)
prec = metrics.precision_score(target, ypred_best)
rec = metrics.recall_score(target, ypred_best)
f1 = metrics.f1_score(target, ypred_best)
print("Matriz de confusión:\n", cm)
print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")
print(f"Accuracy: {acc:.4f}")
print(f"Precision (4top): {prec:.4f}")
print(f"Recall (4top): {rec:.4f}")
print(f"F1-score (4top): {f1:.4f}\n")
print("Classification report:\n", metrics.classification_report(target, ypred_best, digits=4))
# Out:
# Matriz de confusión:
#  [[4033  156]
#  [ 362  449]]
# TN: 4033, FP: 156, FN: 362, TP: 449
# Accuracy: 0.8964
# Precision (4top): 0.7421
# Recall (4top): 0.5536
# F1-score (4top): 0.6342
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9176    0.9628    0.9397      4189
#            1     0.7421    0.5536    0.6342       811
#
#     accuracy                         0.8964      5000
#    macro avg     0.8299    0.7582    0.7869      5000
# weighted avg     0.8892    0.8964    0.8901      5000

# %% [markdown]
# **Construya la matriz de confusión para el modelo optimizado**
#
# Preguntas:
#
# - ¿Cuál es la accuracy del modelo optimizado?
# R: 0.8964
# - ¿Cuál es la precision para la clase 4top?
# R: 0.7421
# - ¿Cuál es el recall para la clase 4top?
# R: 0.5536
# - ¿Cuál es el F1-score para la clase 4top?
# R: 0.6342
# - ¿Qué métrica mejoró más respecto al benchmark lineal?
# R: Mejoró más el recall, con 0.02 puntos más.
# - ¿Qué métrica empeoró o cambió muy poco?
# R: La precisión y el accuracy aumentaron muy ligeramente.
# - ¿La mejora en accuracy refleja una mejora real para la clase 4top?
# R: Sí, aunque sigue siendo baja.
# - ¿El modelo optimizado detecta mejor la clase minoritaria que el benchmark lineal?
# R: Sí, existe un aumento en ~4 puntos porcentuales para el recall de la clase 4top
#
# Complete la tabla de comparación
#
#
# | Modelo            | Accuracy | Precision `4top` | Recall `4top` | F1-score `4top` | Comentario |
# | ----------------- | -------: | ---------------: | ------------: | --------------: | ---------- |
# | Benchmark lineal  |   0.8928 |    0.7469        |  0.5129       |  0.6082         |            |
# | Modelo optimizado |   0.8954 |    0.7483        |    0.5351     |      0.6240     |            |
#
# - ¿El modelo optimizado mejora todas las métricas o solo algunas?
# R: Mejora todas las métricas aunque de manera leve. Una métrica que empeoró levemente fue el recall para la clase negativa.
# - Si una métrica mejora pero otra empeora, ¿cómo decidiría cuál modelo es mejor?
# - Dependiendo del objetivo del modelo, pero siempre buscando un balance entre las métricas, o buscando el modelo que tenga las mejores métricas en general.
# - ¿La mejora justifica usar un modelo más complejo?
# - Sí representó un aumento en la detección de eventos 4top, mas no parece ser la mejor forma de abordar el problema, por lo que habría que buscar alternativas.

# %% [markdown]
# #### Diagnóstico final
#
# - ¿Qué modelo elegiría para reportar y por qué?
# - ¿Qué limitación importante todavía tiene el modelo?

# %% [markdown]
# ## Actividad final: mejorar el modelo
#
# Hasta ahora usamos un conjunto limitado de features para construir y optimizar nuestros modelos. Sin embargo, el desempeño de un modelo no depende solo del algoritmo o de los hiperparámetros: también depende de la información que le entregamos.
#
# En este dataset, cada evento contiene información de varias partículas reconstruidas. Como los eventos `4top` suelen ser más complejos que los eventos `ttbar`, es razonable pensar que usar más información del evento podría ayudar al modelo a distinguir mejor ambas clases.
#
# **Proponga una estrategia para mejorar el modelo explorando nuevas features o usando una representación más completa de los eventos.**
#
# Puede considerar, por ejemplo:
#
# - incluir información de más partículas;
# - usar todas las partículas disponibles;
# - construir variables derivadas;
# - modificar el tratamiento de valores faltantes;
# - comparar distintos subconjuntos de features;
# - cambiar la métrica usada para optimizar el modelo.
#
# Luego evalúe si su propuesta mejora el desempeño respecto al modelo anterior.
#
# ### Preguntas
#
# 1. ¿Qué cambio hizo?
# 4. ¿Mejoró la detección de eventos `4top`?
# 5. ¿Qué ocurrió con la matriz de confusión?
# 6. ¿La mejora justifica el aumento de complejidad?
# 7. ¿Qué aprendió sobre la importancia de las features en este problema?

# %%
features.columns
# Out:
# Index(['MET', 'METphi', 'Type_1', 'P1', 'P2', 'P3', 'P4', 'Type_2', 'P5', 'P6',
#        'P7', 'P8', 'Type_3', 'P9', 'P10', 'P11', 'P12', 'Type_4', 'P13', 'P14',
#        'P15', 'P16', 'Type_5', 'P17', 'P18', 'P19', 'P20', 'Type_6', 'P21',
#        'P22', 'P23', 'P24', 'Type_7', 'P25', 'P26', 'P27', 'P28', 'Type_8',
#        'P29', 'P30', 'P31', 'P32', 'Type_9', 'P33', 'P34', 'P35', 'P36',
#        'Type_10', 'P37', 'P38', 'P39', 'P40', 'Type_11', 'P41', 'P42', 'P43',
#        'P44', 'Type_12', 'P45', 'P46', 'P47', 'P48', 'Type_13', 'P49', 'P50',
#        'P51', 'P52'],
#       dtype='object')

# %%
#Dejaremos hasta la quinta partícula y añadiremos el tipo de partícula resultante


features2 = features.copy()
features2["Type_2"].unique()
encoder = LabelEncoder()

encoder.fit(features2["Type_2"].values)
type_cols = [c for c in features2.columns if c.lower().startswith('type_')]

features2[type_cols] = features2[type_cols].fillna('missing')
encoder.fit(np.unique(features2[type_cols].values.ravel()))

for col in type_cols:
    features2[col] = encoder.transform(features2[col].values)

missing_code = encoder.transform(['missing'])[0]

features2['n_particles'] = (features2[type_cols] != missing_code).sum(axis=1)

for cls in encoder.classes_:
    if cls == 'missing':
        continue
    code = encoder.transform([cls])[0]
    features2[f"n_{cls}"] = (features2[type_cols] == code).sum(axis=1)
p_cols = [c for c in features2.columns if c.startswith("P")]
features2[p_cols] = features2[p_cols].fillna(0)

# %%
# %%time

parameters = {'svc__kernel':['poly', 'rbf'], \
              'svc__gamma':[0.00001,'scale', 0.01, 0.1], 'svc__C':[0.1, 1.0, 10.0, 100.0], \
              'svc__degree': [2, 4, 8]}



model2 = GridSearchCV(piped_model, parameters, cv = StratifiedKFold(n_splits=5, shuffle=True), \
                     verbose = 2, n_jobs = -1, return_train_score=True)
model2.fit(features2,target)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=  -0.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.5s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.3s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.5s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.5s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.5s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.5s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.7s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   2.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=0.1, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   2.0s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.6s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.6s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.8s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.9s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.9s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.0s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=0.1, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.2s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.0s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.6s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.6s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.8s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.1s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.0s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.6s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=0.1, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   5.2s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.6s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.6s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   2.5s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   2.7s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   2.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   2.7s
# [CV] END svc__C=1.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   2.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.6s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.6s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.6s[CV] END svc__C=1.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.5s
#
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.6s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.8s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.8s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.6s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   1.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.9s
# [CV] END svc__C=1.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   2.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.3s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.6s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.7s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.6s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.2s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.9s
# [CV] END svc__C=1.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.3s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=  -0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=  -0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=  -0.0s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=  -0.1s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=  -0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=  -0.5s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=  -0.4s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   0.7s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.0s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.7s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.6s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.6s
# [CV] END svc__C=10.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.7s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   2.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   2.6s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.7s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   2.3s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.8s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   2.6s
# [CV] END svc__C=10.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.9s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   2.7s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.7s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.9s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   1.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.4s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.4s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.7s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   4.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.7s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.6s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   3.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   4.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=poly; total time=   0.8s
# [CV] END svc__C=10.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   4.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.6s[CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.2s
#
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=scale, svc__kernel=rbf; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.7s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.7s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.8s
# [CV] END svc__C=100.0, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf; total time=   3.9s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.01, svc__kernel=poly; total time=   1.6s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.3s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=poly; total time=   1.0s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.9s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=rbf; total time=   0.8s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=1e-05, svc__kernel=poly; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=rbf; total time=   1.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.4s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.6s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   3.0s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   2.5s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.7s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   3.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.7s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   3.1s
# [CV] END svc__C=100.0, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf; total time=   3.8s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   4.8s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   2.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=rbf; total time=   1.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   2.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=scale, svc__kernel=poly; total time=   4.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   2.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.01, svc__kernel=poly; total time=   2.7s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   2.7s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   2.5s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   2.7s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.2s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=poly; total time=   3.1s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.4s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.6s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.3s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   1.8s
# [CV] END svc__C=100.0, svc__degree=8, svc__gamma=0.1, svc__kernel=rbf; total time=   2.0s
# CPU times: user 5.57 s, sys: 3.77 s, total: 9.34 s
# Wall time: 1min 2s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('svc', SVC())]),
#              n_jobs=-1,
#              param_grid={'svc__C': [0.1, 1.0, 10.0, 100.0],
#                          'svc__degree': [2, 4, 8],
#                          'svc__gamma': [1e-05, 'scale', 0.01, 0.1],
#                          'svc__kernel': ['poly', 'rbf']},
#              return_train_score=True, verbose=2)

# %%
print('Best model, accuracy score:', "{:.4f}".format(model2.best_score_), model2.best_params_)
# Out:
# Best model, accuracy score: 0.9434 {'svc__C': 100.0, 'svc__degree': 2, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}

# %%
best_model2 = model2.best_estimator_
ypred_best2 = cross_val_predict(
    best_model2,
    features2,
    target,
    cv=cv
)

cm2 = metrics.confusion_matrix(target, ypred_best2)
tn2, fp2, fn2, tp2 = cm2.ravel()
acc2 = metrics.accuracy_score(target, ypred_best2)
prec2 = metrics.precision_score(target, ypred_best2)
rec2 = metrics.recall_score(target, ypred_best2)
f1_2 = metrics.f1_score(target, ypred_best2)

print("Matriz de confusión:\n", cm2)
print(f"TN: {tn2}, FP: {fp2}, FN: {fn2}, TP: {tp2}")
print(f"Accuracy: {acc2:.4f}")
print(f"Precision (4top): {prec2:.4f}")
print(f"Recall (4top): {rec2:.4f}")
print(f"F1-score (4top): {f1_2:.4f}\n")
print("Classification report:\n", metrics.classification_report(target, ypred_best2, digits=4))
# Out:
# Matriz de confusión:
#  [[4092   97]
#  [ 191  620]]
# TN: 4092, FP: 97, FN: 191, TP: 620
# Accuracy: 0.9424
# Precision (4top): 0.8647
# Recall (4top): 0.7645
# F1-score (4top): 0.8115
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9554    0.9768    0.9660      4189
#            1     0.8647    0.7645    0.8115       811
#
#     accuracy                         0.9424      5000
#    macro avg     0.9101    0.8707    0.8888      5000
# weighted avg     0.9407    0.9424    0.9409      5000

# %% [markdown]
# - Se comenzó por incluir todas los decaimientos generados y cambiar los NaN en los tipos de partículas por "missing". Además, se añadieron columnas que contemplaban el número total de partículas generadas en el evento, además del número total de cada tipo de partícula. Los NaN de los 4-vectores se llenaron con 0.
# - Mejoró bastante, obteniendo un recall de 0.7645 para los eventos 4top-
# - Se redujo considerablemente el número de falsos negativos, que entendemos que son aquellos eventos que son en realidad 4top, pero se clasificaron como ttbar. Ahora un porcentaje de estos pasó a ser bien clasificado en TP. En general, los valores que más cambiaron son FN y TP.
# - Sí, en este caso se consiguió una mejora considerable respecto a los otros modelos haciendo valer la complejidad del modelo.
# - Hay características que no se pueden obviar del problema, más pensando en la situación física que se quiere estudiar y modelar. El tratamiento de las features resulta fundamental como prueba del entendimiento y la extracción de datos importantes, que dan la base para considerar un modelo que responda a los datos.
